# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Based on the examples of graphs you can create using matplotlib, I think it'd be very interesting to create a color map. If I were to explore creating this graph I'd like to do so using a dataset about the ocean. I think this graph could be a cool way to explore the relationship between ocean depths and temperatures.

# %%
sample = pd.read_csv('cces_example_data.csv')
sample.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %% [markdown]
# I noticed in class that we just called .head() function and all of the data still populated the graphs so I have done the same here

# %%
fig1, ax1 = plt.subplots(1, 2, figsize = (12, 4))
ax1[0].hist(x = sample['age'])
ax1[0].set_title('Age Histogram')

ax1[1].scatter(x = sample['age'], y = sample['faminc_new'])
ax1[1].set_title('Political Identity')

plt.show()

# %%
fig2, ax2 = plt.subplots()
ax2.bar(sample['Evaluation'], sample['age'])

plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.scatter(x = sample['ConMediaUse'], y = sample['ImmiPhobia'])

plt.show()
